# %% [markdown]
# ## CAPSTONE PROJECT

# %% [markdown]
# ### Yoga & Meditation shops in New York city

# %% [markdown]
# An entepreneur wants to open 5 tea stores in New York city selling also Yoga, meditation and alternative medicine equipment/books/tools/etc. She wants to find out how Yoga-related venues are distributed in the area, and how efficiently these could be clustered to be served by each of the 5  stores in proximity, optimally within walking distance and with minimum number of river and bridge crossings (to make it easier for cyclists and walkers).
#
# In this notebook we perform the data acquisition, pre-processing, analysis and visualization for identifying a set of five areas of optimal location.

# %% [markdown]
# **Import all necessary dependencies**

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# **Use the Foursquare API**
#
# We will use the Foursquare API for obtaining list of all Yoga Studios

# %% [markdown]
# First we will use the geopy library to get New York City's geographical coordinates

# %%
address = 'New York City, NY'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4a569fd698d> in <module>()
#       1 address = 'New York City, NY'
#       2
# ----> 3 geolocator = Nominatim()
#       4 location = geolocator.geocode(address)
#       5 latitude = location.latitude
#
# NameError: name 'Nominatim' is not defined

# %%
# Putting together the URL for the foursquare api call
CLIENT_ID = 'M1OEMNM3EGHKQ4U3IQZ4WTJWRNTHIGJ4QAH5J4OWWVJYN2ML' # your Foursquare ID
CLIENT_SECRET = 'NWDV3GKRHBDPRSAFZ3QAAUWR5B13HPHHI4DB0TGDKJBIQVYP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
# Radius from the center of New York City 
# and number of venues (LIMIT) to retrieve information on
radius = 5000
LIMIT = 200

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&query=Yoga Studio'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=M1OEMNM3EGHKQ4U3IQZ4WTJWRNTHIGJ4QAH5J4OWWVJYN2ML&client_secret=NWDV3GKRHBDPRSAFZ3QAAUWR5B13HPHHI4DB0TGDKJBIQVYP&ll=40.7308619,-73.9871558&v=20180605&radius=5000&limit=200&query=Yoga Studio'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bd2e9a14434b9406e1705d2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'New York',
#   'headerFullLocation': 'New York',
#   'headerLocationGranularity': 'city',
#   'query': 'yoga studio',
#   'totalResults': 216,
#   'suggestedBounds': {'ne': {'lat': 40.775861945000045,
#     'lng': -73.92788286035417},
#    'sw': {'lat': 40.685861854999956, 'lng': -74.04642873964582}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45367ca4f964a520ab3b1fe3',
#        'name': 'Yoga to the People',
#        'location': {'address': '12 Saint Marks Pl',
#         'crossStreet': 'btwn 2nd & 3rd Ave.',
#         'lat': 40.72898670891247,
#         'lng': -73.98936467240519,
#         'distance': 279,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['12 Saint Marks Pl (btwn 2nd & 3rd Ave.)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85769322'}},
#       'referralId': 'e-0-45367ca4f964a520ab3b1fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b58d651f964a520e36d28e3',
#        'name': 'Yoga Vida',
#        'location': {'address': '99 University Pl',
#         'crossStreet': '6th Floor',
#         'lat': 40.73393700511834,
#         'lng': -73.99268749904417,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73393700511834,
#           'lng': -73.99268749904417}],
#         'distance': 578,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['99 University Pl (6th Floor)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b58d651f964a520e36d28e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f2425cce4b0e12081504088',
#        'name': 'Modo Yoga NYC',
#        'location': {'address': '434 Avenue of the Americas',
#         'crossStreet': '10th Street',
#         'lat': 40.734674447348816,
#         'lng': -73.99867000971622,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.734674447348816,
#           'lng': -73.99867000971622}],
#         'distance': 1059,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['434 Avenue of the Americas (10th Street)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f2425cce4b0e12081504088-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5a48d8185036bc29efb979',
#        'name': 'Sacred Sounds Yoga',
#        'location': {'address': '163 Bleecker St Fl 2',
#         'crossStreet': 'btwn Sullivan & Thompson St.',
#         'lat': 40.72863771916715,
#         'lng': -74.00011526297406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72863771916715,
#           'lng': -74.00011526297406}],
#         'distance': 1120,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['163 Bleecker St Fl 2 (btwn Sullivan & Thompson St.)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37011604'}},
#       'referralId': 'e-0-4e5a48d8185036bc29efb979-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45312392f964a5206e3b1fe3',
#        'name': 'Jivamukti Yoga School NYC',
#        'location': {'address': '841 Broadway Fl 2',
#         'crossStreet': 'btwn 13th & 14th St',
#         'lat': 40.73431360000001,
#         'lng': -73.9911839,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73431360000001,
#           'lng': -73.9911839}],
#         'distance': 512,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['841 Broadway Fl 2 (btwn 13th & 14th St)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54385821'}},
#       'referralId': 'e-0-45312392f964a5206e3b1fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de56910fa764cf4bec7dd4e',
#        'name': 'Yoga Vida',
#        'location': {'address': '666 Broadway',
#         'crossStreet': 'at Bond St',
#         'lat': 40.7270016507027,
#         'lng': -73.99522462200933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7270016507027,
#           'lng': -73.99522462200933}],
#         'distance': 804,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['666 Broadway (at Bond St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de56910fa764cf4bec7dd4e-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd31e409854d13a8de7fc4d',
#        'name': 'Laughing Lotus Yoga Center',
#        'location': {'address': '636 Sixth Ave. 3rd Fl (entrance is on 19th St)',
#         'crossStreet': 'at 6th Ave',
#         'lat': 40.74036142113778,
#         'lng': -73.99431420336869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74036142113778,
#           'lng': -73.99431420336869}],
#         'distance': 1217,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['636 Sixth Ave. 3rd Fl (entrance is on 19th St) (at 6th Ave)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43033198'}},
#       'referralId': 'e-0-4bd31e409854d13a8de7fc4d-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6768e2f964a5202a4d2be3',
#        'name': 'Strala Yoga',
#        'location': {'address': '632 Broadway',
#         'crossStreet': 'at E Houston St.',
#         'lat': 40.7262753864165,
#         'lng': -73.99605507291461,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7262753864165,
#           'lng': -73.99605507291461}],
#         'distance': 907,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['632 Broadway (at E Houston St.)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6768e2f964a5202a4d2be3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5707fa79498e89088b4bf74c',
#        'name': 'Y7 Yoga',
#        'location': {'address': 'E 11th St',
#         'crossStreet': 'btwn Broadway & University Pl',
#         'lat': 40.733007,
#         'lng': -73.992346,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.733007,
#           'lng': -73.992346}],
#         'distance': 498,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['E 11th St (btwn Broadway & University Pl)',
#          'New York, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5707fa79498e89088b4bf74c-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aad1805f964a5207e5e20e3',
#        'name': 'East Yoga',
#        'location': {'address': '96 Avenue B',
#         'crossStreet': 'at 6th Street',
#         'lat': 40.724669180392745,
#         'lng': -73.98155789865694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.724669180392745,
#           'lng': -73.98155789865694}],
#         'distance': 835,
#         'postalCode': '10009',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['96 Avenue B (at 6th Street)',
#          'New York, NY 10009',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aad1805f964a5207e5e20e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c261716f1272d7fb4d985c5',
#        'name': 'YOGAMAYA New York',
#        'location': {'address': '135 W 20th St',
#         'crossStreet': 'btwn 6th & 7th Ave.',
#         'lat': 40.74169772133005,
#         'lng': -73.99572973472985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74169772133005,
#           'lng': -73.99572973472985}],
#         'distance': 1406,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['135 W 20th St (btwn 6th & 7th Ave.)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34300335'}},
#       'referralId': 'e-0-4c261716f1272d7fb4d985c5-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a81fe22f964a52042f81fe3',
#        'name': 'ISHTA Yoga',
#        'location': {'address': '56 E 11th St',
#         'crossStreet': 'btwn University and Broadway',
#         'lat': 40.73299563501212,
#         'lng': -73.9924887258101,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73299563501212,
#           'lng': -73.9924887258101}],
#         'distance': 508,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['56 E 11th St (btwn University and Broadway)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '74141204'}},
#       'referralId': 'e-0-4a81fe22f964a52042f81fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5522fc1a498e7b7b2bfb6a64',
#        'name': 'Y7 Studio Flatiron',
#        'location': {'address': '25 W 23rd St',
#         'crossStreet': 'between 5th Ave and Ave of the Americas',
#         'lat': 40.742028916501894,
#         'lng': -73.9905607853857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742028916501894,
#           'lng': -73.9905607853857}],
#         'distance': 1275,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['25 W 23rd St (between 5th Ave and Ave of the Americas)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5522fc1a498e7b7b2bfb6a64-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3fef94f964a5201ba41fe3',
#        'name': 'Integral Yoga Institute New York',
#        'location': {'address': '227 W 13th St',
#         'crossStreet': 'btwn 7th & 8th Avenues',
#         'lat': 40.73845716301498,
#         'lng': -74.00152714949196,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73845716301498,
#           'lng': -74.00152714949196}],
#         'distance': 1477,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['227 W 13th St (btwn 7th & 8th Avenues)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3fef94f964a5201ba41fe3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b550c78f964a5203ad927e3',
#        'name': 'Studio Anya',
#        'location': {'lat': 40.74332930109508,
#         'lng': -73.99189878314843,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74332930109508,
#           'lng': -73.99189878314843}],
#         'distance': 1444,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '44558546'}},
#       'referralId': 'e-0-4b550c78f964a5203ad927e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7b4ffdf964a520a6ea1fe3',
#        'name': 'The Shala',
#        'location': {'address': '815 Broadway Fl 2',
#         'crossStreet': 'at E 12th St',
#         'lat': 40.733064575617,
#         'lng': -73.9911556783281,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.733064575617,
#           'lng': -73.9911556783281}],
#         'distance': 417,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['815 Broadway Fl 2 (at E 12th St)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7b4ffdf964a520a6ea1fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '577327b6498e4811c0a92800',
#        'name': 'Woom Center',
#        'location': {'address': '274 Bowery Apt 2',
#         'lat': 40.7237194263035,
#         'lng': -73.99285769174772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7237194263035,
#           'lng': -73.99285769174772}],
#         'distance': 929,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['274 Bowery Apt 2',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-577327b6498e4811c0a92800-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55b51009498e4c7fd1fea655',
#        'name': 'New Love City',
#        'location': {'address': '68 Greenpoint Ave #4',
#         'crossStreet': 'Franklin',
#         'lat': 40.729760304268,
#         'lng': -73.95824733769165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.729760304268,
#           'lng': -73.95824733769165}],
#         'distance': 2441,
#         'postalCode': '11222',
#         'cc': 'US',
#         'city': 'Brooklyn',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['68 Greenpoint Ave #4 (Franklin)',
#          'Brooklyn, NY 11222',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '136295990'}},
#       'referralId': 'e-0-55b51009498e4c7fd1fea655-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f458580e4b0288c74fd21fc',
#        'name': 'Stanton Street Yoga',
#        'location': {'address': '196a Stanton St',
#         'crossStreet': 'Attorney St',
#         'lat': 40.71990787398364,
#         'lng': -73.98311496524775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71990787398364,
#           'lng': -73.98311496524775}],
#         'distance': 1266,
#         'postalCode': '10002',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['196a Stanton St (Attorney St)',
#          'New York, NY 10002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '56324641'}},
#       'referralId': 'e-0-4f458580e4b0288c74fd21fc-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f8b4309e4b00a626392fa85',
#        'name': 'Om Factory',
#        'location': {'address': '873 Broadway',
#         'crossStreet': '18th St.',
#         'lat': 40.73799001734185,
#         'lng': -73.99040326955952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73799001734185,
#           'lng': -73.99040326955952}],
#         'distance': 839,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['873 Broadway (18th St.)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f8b4309e4b00a626392fa85-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b67625ef964a520a54b2be3',
#        'name': 'Reflections Center for Conscious Living & Yoga',
#        'location': {'address': '227 E 24th St',
#         'crossStreet': '2nd & 3rd Aves.',
#         'lat': 40.73905027871491,
#         'lng': -73.98148705717242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73905027871491,
#           'lng': -73.98148705717242}],
#         'distance': 1029,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['227 E 24th St (2nd & 3rd Aves.)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71355734'}},
#       'referralId': 'e-0-4b67625ef964a520a54b2be3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506c8a40e4b01c5d04691665',
#        'name': 'Bikram Yoga Herald Square',
#        'location': {'address': '139 West 35 Street, Floor 8',
#         'crossStreet': 'btwn Broadway & 7th Ave',
#         'lat': 40.75123304473457,
#         'lng': -73.98907338625028,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.75123304473457,
#           'lng': -73.98907338625028}],
#         'distance': 2273,
#         'postalCode': '10123',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['139 West 35 Street, Floor 8 (btwn Broadway & 7th Ave)',
#          'New York, NY 10123',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43751848'}},
#       'referralId': 'e-0-506c8a40e4b01c5d04691665-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b9346d498ef55d203d8696',
#        'name': 'Y7 Studio - Soho',
#        'location': {'address': '430 Broome St Fl 2',
#         'lat': 40.721440655284646,
#         'lng': -73.99893612207057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.721440655284646,
#           'lng': -73.99893612207057}],
#         'distance': 1444,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['430 Broome St Fl 2',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '116912566'}},
#       'referralId': 'e-0-54b9346d498ef55d203d8696-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adf2ccff964a520057821e3',
#        'name': 'Bode NYC - Flatiron',
#        'location': {'address': '182 5th Ave',
#         'crossStreet': '22nd St',
#         'lat': 40.74129619715311,
#         'lng': -73.98979509360808,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74129619715311,
#           'lng': -73.98979509360808}],
#         'distance': 1182,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['182 5th Ave (22nd St)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adf2ccff964a520057821e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af71ba2f964a520ee0522e3',
#        'name': 'Sal Anthony’s Movement Salon',
#        'location': {'address': '190 3rd Ave',
#         'crossStreet': 'at 17th St.',
#         'lat': 40.73534717012308,
#         'lng': -73.98575057992092,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73534717012308,
#           'lng': -73.98575057992092}],
#         'distance': 513,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['190 3rd Ave (at 17th St.)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af71ba2f964a520ee0522e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a778d7ff964a520c8e41fe3',
#        'name': 'Yoga to the People',
#        'location': {'address': '115 W 27th St Fl 3',
#         'crossStreet': 'btwn 6th & 7th Ave',
#         'lat': 40.7457778869765,
#         'lng': -73.99166961207493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7457778869765,
#           'lng': -73.99166961207493}],
#         'distance': 1703,
#         'postalCode': '10001',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['115 W 27th St Fl 3 (btwn 6th & 7th Ave)',
#          'New York, NY 10001',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a778d7ff964a520c8e41fe3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3449eaf964a5200a9c1fe3',
#        'name': 'YogaWorks Soho',
#        'location': {'address': '459 Broadway',
#         'crossStreet': 'at Grand',
#         'lat': 40.720861,
#         'lng': -74.000868,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.720861,
#           'lng': -74.000868}],
#         'distance': 1605,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['459 Broadway (at Grand)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3449eaf964a5200a9c1fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53223bc3498e7a57240f0cdc',
#        'name': 'Yoga Shanti - NYC',
#        'location': {'address': '46 W 24th Street, Ground Floor',
#         'crossStreet': '5th & 6th ave',
#         'lat': 40.74330639013951,
#         'lng': -73.99187341026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74330639013951,
#           'lng': -73.99187341026}],
#         'distance': 1441,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['46 W 24th Street, Ground Floor (5th & 6th ave)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '82213387'}},
#       'referralId': 'e-0-53223bc3498e7a57240f0cdc-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553527eb498e43895e4c1805',
#        'name': 'SKY TING YOGA',
#        'location': {'address': '55 Chrystie St',
#         'crossStreet': 'btwn Hester & Canal',
#         'lat': 40.71646917184756,
#         'lng': -73.99501982858183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71646917184756,
#           'lng': -73.99501982858183}],
#         'distance': 1734,
#         'postalCode': '10002',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['55 Chrystie St (btwn Hester & Canal)',
#          'New York, NY 10002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553527eb498e43895e4c1805-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582dbaabd21e031c1a35423d',
#        'name': 'SKY TING YOGA',
#        'location': {'address': '381 Broadway',
#         'lat': 40.71812415369316,
#         'lng': -74.00305076100503,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71812415369316,
#           'lng': -74.00305076100503}],
#         'distance': 1951,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['381 Broadway',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582dbaabd21e031c1a35423d-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ae10e4498eb3e48cc40981',
#        'name': 'CrossFit East River',
#        'location': {'address': '647 E 9th St',
#         'crossStreet': 'Avenue C',
#         'lat': 40.7254434939673,
#         'lng': -73.97846140631547,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7254434939673,
#           'lng': -73.97846140631547}],
#         'distance': 949,
#         'postalCode': '10009',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['647 E 9th St (Avenue C)',
#          'New York, NY 10009',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '185733414'}},
#       'referralId': 'e-0-51ae10e4498eb3e48cc40981-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa7cf24f964a520534d20e3',
#        'name': 'Iyengar Yoga Institute',
#        'location': {'address': '150 W 22nd St',
#         'crossStreet': '6th Ave',
#         'lat': 40.74312103171785,
#         'lng': -73.99529114536165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74312103171785,
#           'lng': -73.99529114536165}],
#         'distance': 1527,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['150 W 22nd St (6th Ave)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa7cf24f964a520534d20e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56939812498ee79afe6b3fc6',
#        'name': 'Modo Yoga Williamsburg',
#        'location': {'address': '109 Metropolitan',
#         'crossStreet': 'Wythe',
#         'lat': 40.71667272570606,
#         'lng': -73.96311393945952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71667272570606,
#           'lng': -73.96311393945952}],
#         'distance': 2570,
#         'postalCode': '11249',
#         'cc': 'US',
#         'city': 'Brooklyn',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['109 Metropolitan (Wythe)',
#          'Brooklyn, NY 11249',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56939812498ee79afe6b3fc6-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af0e05cf964a520d7df21e3',
#        'name': 'New York Health and Racquet Club',
#        'location': {'address': '270 Park Ave S',
#         'crossStreet': 'btwn E 21st & E 22nd St',
#         'lat': 40.739025987866704,
#         'lng': -73.98728715915878,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.739025987866704,
#           'lng': -73.98728715915878}],
#         'distance': 908,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['270 Park Ave S (btwn E 21st & E 22nd St)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36095120'}},
#       'referralId': 'e-0-4af0e05cf964a520d7df21e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5acbcbf9a22db75a79ba404a',
#        'name': 'Humming Puppy',
#        'location': {'address': '119 W 23rd St',
#         'lat': 40.74320720431982,
#         'lng': -73.99337849002711,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74320720431982,
#           'lng': -73.99337849002711}],
#         'distance': 1471,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['119 W 23rd St',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5acbcbf9a22db75a79ba404a-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7e98f7f964a5209ef42fe3',
#        'name': "mang'Oh yoga",
#        'location': {'address': '322 E 39th St',
#         'crossStreet': 'btw 1st & 2nd Ave.',
#         'lat': 40.74744599731651,
#         'lng': -73.9726136084391,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74744599731651,
#           'lng': -73.9726136084391}],
#         'distance': 2216,
#         'postalCode': '10016',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['322 E 39th St (btw 1st & 2nd Ave.)',
#          'New York, NY 10016',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '205104351'}},
#       'referralId': 'e-0-4b7e98f7f964a5209ef42fe3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad79413f964a520610c21e3',
#        'name': 'Kula Yoga Project',
#        'location': {'address': '28 Warren St',
#         'crossStreet': 'Church St',
#         'lat': 40.714342290158086,
#         'lng': -74.00809356840004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714342290158086,
#           'lng': -74.00809356840004}],
#         'distance': 2549,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['28 Warren St (Church St)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad79413f964a520610c21e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7ca51ff964a52012ed1fe3',
#        'name': 'Physique 57',
#        'location': {'address': '161 Ave of the Americas',
#         'crossStreet': 'at Spring St',
#         'lat': 40.72583480849319,
#         'lng': -74.00399845123462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72583480849319,
#           'lng': -74.00399845123462}],
#         'distance': 1527,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['161 Ave of the Americas (at Spring St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7ca51ff964a52012ed1fe3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8a2e20050b713b7ccba3b',
#        'name': 'Shambhala Meditation Center of New York',
# ...
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae89ee6f964a520f2b021e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4558b83bf964a5204b3d1fe3',
#        'name': 'New York Health and Racquet Club',
#        'location': {'address': '60 W 23rd St',
#         'crossStreet': 'at 6th Ave',
#         'lat': 40.74257351738011,
#         'lng': -73.99241203373882,
#         'distance': 1377,
#         'postalCode': '10010',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['60 W 23rd St (at 6th Ave)',
#          'New York, NY 10010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36095134'}},
#       'referralId': 'e-0-4558b83bf964a5204b3d1fe3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589ba7a9005a0f1cef4dd484',
#        'name': 'MNDFL Meditation',
#        'location': {'lat': 40.717358419048516,
#         'lng': -73.95547240129777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.717358419048516,
#           'lng': -73.95547240129777}],
#         'distance': 3066,
#         'cc': 'US',
#         'city': 'Brooklyn',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Brooklyn, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589ba7a9005a0f1cef4dd484-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa968b7e4b07cb43c311f1c',
#        'name': 'Area Yoga & Spa',
#        'location': {'address': '144 Montague St',
#         'crossStreet': 'Henry',
#         'lat': 40.69456810543555,
#         'lng': -73.99351424019754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.69456810543555,
#           'lng': -73.99351424019754}],
#         'distance': 4075,
#         'postalCode': '11201',
#         'cc': 'US',
#         'city': 'Brooklyn',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['144 Montague St (Henry)',
#          'Brooklyn, NY 11201',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63535873'}},
#       'referralId': 'e-0-4fa968b7e4b07cb43c311f1c-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac259d0f964a520ca9820e3',
#        'name': 'Earth Yoga NYC',
#        'location': {'address': '328 E 61st St',
#         'crossStreet': 'Btw 1st and 2nd Avenue',
#         'lat': 40.76127072190423,
#         'lng': -73.96204547441614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.76127072190423,
#           'lng': -73.96204547441614}],
#         'distance': 3992,
#         'postalCode': '10065',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['328 E 61st St (Btw 1st and 2nd Avenue)',
#          'New York, NY 10065',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '68792328'}},
#       'referralId': 'e-0-4ac259d0f964a520ca9820e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a05d2abf964a52081721fe3',
#        'name': 'Equinox Highline',
#        'location': {'address': '100 10th Avenue',
#         'crossStreet': 'at W 17th St',
#         'lat': 40.743818,
#         'lng': -74.006759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743818,
#           'lng': -74.006759}],
#         'distance': 2194,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['100 10th Avenue (at W 17th St)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a05d2abf964a52081721fe3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b36e468f964a520e03d25e3',
#        'name': 'Exhale Central Park South',
#        'location': {'address': '150 Central Park S',
#         'crossStreet': 'btwn 6th & 7th Ave',
#         'lat': 40.766284312080735,
#         'lng': -73.97767773874658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.766284312080735,
#           'lng': -73.97767773874658}],
#         'distance': 4023,
#         'postalCode': '10019',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['150 Central Park S (btwn 6th & 7th Ave)',
#          'New York, NY 10019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b36e468f964a520e03d25e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0a945ef2c1236a74ccfc56',
#        'name': 'Equinox Printing House',
#        'location': {'address': '421 Hudson St.',
#         'crossStreet': 'btwn Clarkson & Leroy St',
#         'lat': 40.72965,
#         'lng': -74.007128,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72965,
#           'lng': -74.007128}],
#         'distance': 1690,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['421 Hudson St. (btwn Clarkson & Leroy St)',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0a945ef2c1236a74ccfc56-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a940e03f964a520472020e3',
#        'name': 'Physique 57',
#        'location': {'address': '24 W 57th St',
#         'crossStreet': 'btwn 5th & 6th Ave',
#         'lat': 40.76374341560388,
#         'lng': -73.97559190296822,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.76374341560388,
#           'lng': -73.97559190296822}],
#         'distance': 3788,
#         'postalCode': '10019',
#         'cc': 'US',
#         'neighborhood': 'Midtown',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['24 W 57th St (btwn 5th & 6th Ave)',
#          'New York, NY 10019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a940e03f964a520472020e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d73e6e49d2fa1430d58e9d6',
#        'name': 'Yo Yoga! NYC',
#        'location': {'address': '344 E 59th St',
#         'crossStreet': '1st Ave',
#         'lat': 40.75976134132783,
#         'lng': -73.96253231505861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.75976134132783,
#           'lng': -73.96253231505861}],
#         'distance': 3829,
#         'postalCode': '10022',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['344 E 59th St (1st Ave)',
#          'New York, NY 10022',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d73e6e49d2fa1430d58e9d6-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5cd37cf964a520f04529e3',
#        'name': 'Surya Yoga Academy',
#        'location': {'address': '618 Washington St',
#         'crossStreet': '6th St.',
#         'lat': 40.744101667075846,
#         'lng': -74.02900706503569,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.744101667075846,
#           'lng': -74.02900706503569}],
#         'distance': 3825,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['618 Washington St (6th St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41891030'}},
#       'referralId': 'e-0-4b5cd37cf964a520f04529e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49c943d2f964a5204f581fe3',
#        'name': 'Equinox Park Avenue',
#        'location': {'address': '1 Park Ave',
#         'crossStreet': 'btwn E 32nd & E 33rd St',
#         'lat': 40.746093,
#         'lng': -73.98135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.746093,
#           'lng': -73.98135}],
#         'distance': 1764,
#         'postalCode': '10016',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1 Park Ave (btwn E 32nd & E 33rd St)',
#          'New York, NY 10016',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49c943d2f964a5204f581fe3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59b1b5e12a7ab6050123b1d5',
#        'name': 'Heatwise',
#        'location': {'address': '163 Remsen St',
#         'lat': 40.69344993357843,
#         'lng': -73.99178782395664,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.69344993357843,
#           'lng': -73.99178782395664}],
#         'distance': 4182,
#         'postalCode': '11201',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['163 Remsen St',
#          'New York, NY 11201',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59b1b5e12a7ab6050123b1d5-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f306558e4b047964c5eaa52',
#        'name': 'The Muse',
#        'location': {'address': '350 Moffat St',
#         'crossStreet': 'Moffat Street',
#         'lat': 40.71545990842143,
#         'lng': -73.96626068465102,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71545990842143,
#           'lng': -73.96626068465102}],
#         'distance': 2459,
#         'postalCode': '11207',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['350 Moffat St (Moffat Street)',
#          'New York, NY 11207',
#          'United States']},
#        'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'shortName': 'Athletics & Sports',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f306558e4b047964c5eaa52-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Clean the JSON and structureit into a pandas dataframe

venues = results['response']['groups'][0]['items']
    
yoga_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
yoga_venues = yoga_venues.loc[:, filtered_columns]

# filter the category for each row
yoga_venues['venue.categories'] = yoga_venues.apply(get_category_type, axis=1)

# clean columns
yoga_venues.columns = [col.split(".")[-1] for col in yoga_venues.columns]

yoga_venues.shape
# Out:
# (100, 4)

# %%
yoga_venues.head()
# Out:
#                         name   categories        lat        lng
# 0         Yoga to the People  Yoga Studio  40.728987 -73.989365
# 1                  Yoga Vida  Yoga Studio  40.733937 -73.992687
# 2              Modo Yoga NYC  Yoga Studio  40.734674 -73.998670
# 3         Sacred Sounds Yoga  Yoga Studio  40.728638 -74.000115
# 4  Jivamukti Yoga School NYC  Yoga Studio  40.734314 -73.991184

# %% [markdown]
# **Create a map of New York with Yoga-related venues superimposed on top**

# %%
# create map of New York using latitude and longitude values

map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map

for lat, lng, name in zip(yoga_venues['lat'], yoga_venues['lng'], yoga_venues['name']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Clustering**
#
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

yoga_venues_clustering = yoga_venues.drop(['name','categories'],1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0, n_init = 10).fit(yoga_venues_clustering)

# check cluster labels generated for each row in the dataframe

kmeans.labels_[0:10]
# Out:
# array([2, 0, 0, 2, 0, 2, 0, 2, 0, 2], dtype=int32)

# %%
# add clustering labels
yoga_venues['Cluster Labels'] = kmeans.labels_

# %%
yoga_venues.head()
# Out:
#                         name   categories        lat        lng  \
# 0         Yoga to the People  Yoga Studio  40.728987 -73.989365
# 1                  Yoga Vida  Yoga Studio  40.733937 -73.992687
# 2              Modo Yoga NYC  Yoga Studio  40.734674 -73.998670
# 3         Sacred Sounds Yoga  Yoga Studio  40.728638 -74.000115
# 4  Jivamukti Yoga School NYC  Yoga Studio  40.734314 -73.991184
#
#    Cluster Labels
# 0               2
# 1               0
# 2               0
# 3               2
# 4               0

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map

markers_colors = []
for lat, lon, name, cluster in zip(yoga_venues['lat'], yoga_venues['lng'], yoga_venues['name'],yoga_venues['Cluster Labels']):
    label = folium.Popup(str(name) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
